# %%
import pandas as pd

# %%
df = pd.read_excel("../data/orders_dataset.xlsx")

# %%
df.head()
# Out:
#    Order_ID Customer_ID  Order_Date Delivery_Date Product_Category Region  \
# 0      1001        C015  2024-01-13    2024-01-18         Clothing  South
# 1      1002        C070  2024-02-14    2024-02-24          Grocery  North
# 2      1003        C078  2024-01-14    2024-01-23         Clothing   West
# 3      1004        C001  2024-03-22    2024-03-29        Furniture   East
# 4      1005        C049  2024-02-19    2024-02-25        Furniture   East
#
#    Sales_Amount  Quantity  Discount  Profit  Delivery_Days Is_Delayed
# 0          3216         2         0  756.85              5         No
# 1           291         1         5   28.09             10        Yes
# 2          2038         2        20  -90.41              9        Yes
# 3          1080         2        10   22.08              7        Yes
# 4          1594         1        15   91.25              6        Yes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          300 non-null    int64
#  1   Customer_ID       300 non-null    str
#  2   Order_Date        300 non-null    str
#  3   Delivery_Date     300 non-null    str
#  4   Product_Category  300 non-null    str
#  5   Region            300 non-null    str
#  6   Sales_Amount      300 non-null    int64
#  7   Quantity          300 non-null    int64
#  8   Discount          300 non-null    int64
#  9   Profit            300 non-null    float64
#  10  Delivery_Days     300 non-null    int64
#  11  Is_Delayed        300 non-null    str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 28.3 KB

# %%
df.describe()
# Out:
#           Order_ID  Sales_Amount    Quantity    Discount       Profit  \
# count   300.000000      300.0000  300.000000  300.000000   300.000000
# mean   1150.500000     3147.2200    3.046667   10.066667   336.659633
# std      86.746758     2285.4192    1.403944    7.094363   481.834124
# min    1001.000000      113.0000    1.000000    0.000000  -516.840000
# 25%    1075.750000     1227.0000    2.000000    5.000000    32.897500
# 50%    1150.500000     2632.5000    3.000000   10.000000   164.040000
# 75%    1225.250000     4622.2500    4.000000   15.000000   525.900000
# max    1300.000000     9950.0000    5.000000   20.000000  2698.550000
#
#        Delivery_Days
# count     300.000000
# mean        5.440000
# std         2.797467
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_ID         0
# Order_Date          0
# Delivery_Date       0
# Product_Category    0
# Region              0
# Sales_Amount        0
# Quantity            0
# Discount            0
# Profit              0
# Delivery_Days       0
# Is_Delayed          0
# dtype: int64

# %%
len(df)
# Out:
# 300

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_ID         0
# Order_Date          0
# Delivery_Date       0
# Product_Category    0
# Region              0
# Sales_Amount        0
# Quantity            0
# Discount            0
# Profit              0
# Delivery_Days       0
# Is_Delayed          0
# dtype: int64

# %%
len(df)
# Out:
# 300

# %%
df.dtypes
# Out:
# Order_ID              int64
# Customer_ID             str
# Order_Date              str
# Delivery_Date           str
# Product_Category        str
# Region                  str
# Sales_Amount          int64
# Quantity              int64
# Discount              int64
# Profit              float64
# Delivery_Days         int64
# Is_Delayed              str
# dtype: object

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df['Delivery_Date']=pd.to_datetime(df['Delivery_Date'])

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# Order_ID                     int64
# Customer_ID                    str
# Order_Date          datetime64[us]
# Delivery_Date       datetime64[us]
# Product_Category               str
# Region                         str
# Sales_Amount                 int64
# Quantity                     int64
# Discount                     int64
# Profit                     float64
# Delivery_Days                int64
# Is_Delayed                     str
# dtype: object

# %%
df.dtypes
# Out:
# Order_ID                     int64
# Customer_ID                    str
# Order_Date          datetime64[us]
# Delivery_Date       datetime64[us]
# Product_Category               str
# Region                         str
# Sales_Amount                 int64
# Quantity                     int64
# Discount                     int64
# Profit                     float64
# Delivery_Days                int64
# Is_Delayed                     str
# dtype: object

# %%
df['Delivery_days']= (df['Delivery_Date']-df['Order_Date']).dt.days

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          300 non-null    int64
#  1   Customer_ID       300 non-null    str
#  2   Order_Date        300 non-null    datetime64[us]
#  3   Delivery_Date     300 non-null    datetime64[us]
#  4   Product_Category  300 non-null    str
#  5   Region            300 non-null    str
#  6   Sales_Amount      300 non-null    int64
#  7   Quantity          300 non-null    int64
#  8   Discount          300 non-null    int64
#  9   Profit            300 non-null    float64
#  10  Delivery_Days     300 non-null    int64
#  11  Is_Delayed        300 non-null    str
#  12  Delivery_days     300 non-null    int64
# dtypes: datetime64[us](2), float64(1), int64(6), str(4)
# memory usage: 30.6 KB

# %%
df.head()
# Out:
#    Order_ID Customer_ID Order_Date Delivery_Date Product_Category Region  \
# 0      1001        C015 2024-01-13    2024-01-18         Clothing  South
# 1      1002        C070 2024-02-14    2024-02-24          Grocery  North
# 2      1003        C078 2024-01-14    2024-01-23         Clothing   West
# 3      1004        C001 2024-03-22    2024-03-29        Furniture   East
# 4      1005        C049 2024-02-19    2024-02-25        Furniture   East
#
#    Sales_Amount  Quantity  Discount  Profit  Delivery_Days Is_Delayed  \
# 0          3216         2         0  756.85              5         No
# 1           291         1         5   28.09             10        Yes
# 2          2038         2        20  -90.41              9        Yes
# 3          1080         2        10   22.08              7        Yes
# 4          1594         1        15   91.25              6        Yes
#
#    Delivery_days
# 0              5
# 1             10
# 2              9
# 3              7
# ...

# %%
df['Sales_Amount'].sum()
# Out:
# np.int64(944166)

# %%
df.groupby('Region')['Sales_Amount'].sum()
# Out:
# Region
# East     219158
# North    214029
# South    266540
# West     244439
# Name: Sales_Amount, dtype: int64

# %%
df.groupby('Region')['Sales_Amount'].sum().sort_values(ascending=False)
# Out:
# Region
# South    266540
# West     244439
# East     219158
# North    214029
# Name: Sales_Amount, dtype: int64

# %%
df.groupby('Region')['Profit'].sum().idxmax()
# Out:
# 'South'

# %%
df.groupby('Region')[['Sales_Amount','Profit']].sum()
# Out:
#         Sales_Amount    Profit
# Region
# East          219158  21644.81
# North         214029  22962.93
# South         266540  31630.20
# West          244439  24759.95

# %%
Region_perf=df.groupby('Region')[['Sales_Amount','Profit']].sum()

# %%
Region_perf['Profit_Margin']= Region_perf['Profit']/Region_perf['Sales_Amount']

# %%
Region_perf
# Out:
#         Sales_Amount    Profit  Profit_Margin
# Region
# East          219158  21644.81       0.098763
# North         214029  22962.93       0.107289
# South         266540  31630.20       0.118670
# West          244439  24759.95       0.101293

# %%
Region_perf.sort_values(by='Profit_Margin', ascending=False)
# Out:
#         Sales_Amount    Profit  Profit_Margin
# Region
# South         266540  31630.20       0.118670
# North         214029  22962.93       0.107289
# West          244439  24759.95       0.101293
# East          219158  21644.81       0.098763

# %%
df.groupby('Product_Category')['Sales_Amount'].sum()
# Out:
# Product_Category
# Clothing       199202
# Electronics    184883
# Furniture      168986
# Grocery        194767
# Sports         196328
# Name: Sales_Amount, dtype: int64

# %%
df.groupby('Product_Category')['Sales_Amount'].sum().idxmax()
# Out:
# 'Clothing'

# %%
df.groupby('Product_Category')['Profit'].sum()
# Out:
# Product_Category
# Clothing       18079.45
# Electronics    21473.79
# Furniture      20667.32
# Grocery        19184.46
# Sports         21592.87
# Name: Profit, dtype: float64

# %%
df.groupby('Product_Category')['Profit'].sum().idxmax()
# Out:
# 'Sports'

# %%
cat_perf = df.groupby('Product_Category')[['Sales_Amount','Profit']].sum()

# %%
cat_perf
# Out:
#                   Sales_Amount    Profit
# Product_Category
# Clothing                199202  18079.45
# Electronics             184883  21473.79
# Furniture               168986  20667.32
# Grocery                 194767  19184.46
# Sports                  196328  21592.87

# %%
cat_perf['Profit_Margin']=cat_perf['Profit']/cat_perf['Sales_Amount']

# %%
cat_perf
# Out:
#                   Sales_Amount    Profit  Profit_Margin
# Product_Category
# Clothing                199202  18079.45       0.090759
# Electronics             184883  21473.79       0.116148
# Furniture               168986  20667.32       0.122302
# Grocery                 194767  19184.46       0.098500
# Sports                  196328  21592.87       0.109984

# %%
cat_perf.sort_values(by='Profit_Margin', ascending=False)
# Out:
#                   Sales_Amount    Profit  Profit_Margin
# Product_Category
# Furniture               168986  20667.32       0.122302
# Electronics             184883  21473.79       0.116148
# Sports                  196328  21592.87       0.109984
# Grocery                 194767  19184.46       0.098500
# Clothing                199202  18079.45       0.090759

# %%
cat_perf['Sales_Amount'].plot(kind='bar')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='Product_Category'>

# %%
import seaborn as sns

sns.barplot(x=cat_perf.index, y=cat_perf['Profit_Margin'])
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 import seaborn as sns
#       2
#       3 sns.barplot(x=cat_perf.index, y=cat_perf['Profit_Margin'])
# ----> 4 plot.show()
#
# NameError: name 'plot' is not defined

# %%
df['Is_Delayed'].value_counts()
# Out:
# Is_Delayed
# No     154
# Yes    146
# Name: count, dtype: int64

# %%
df.groupby('Region')['Is_Delayed'].value_counts()
# Out:
# Region  Is_Delayed
# East    No            36
#         Yes           35
# North   Yes           35
#         No            34
# South   No            46
#         Yes           36
# West    Yes           40
#         No            38
# Name: count, dtype: int64

# %%
df.groupby('Is_Delayed')['Profit'].mean()
# Out:
# Is_Delayed
# No     347.690325
# Yes    325.024521
# Name: Profit, dtype: float64

# %%
df.to_csv('cleaned_sales_data.csv', index=False)

# %%
## Key Business Insights

- South region recorded highest sales and profit.
- Furniture category achieved highest profit margin.
- West region experienced maximum delivery delays.
- Delivery delays negatively impacted profitability.

# %%
The analysis identified strong-performing regions and operational bottlenecks affecting profitability. Power BI dashboards were created to support data-driven business decision-making.
